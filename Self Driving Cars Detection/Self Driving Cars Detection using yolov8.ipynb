# %% [markdown]
# # Unzip Dataset

# %%
#!unzip "/content/drive/MyDrive/Self Driving Cars/Self Driving Cars Dataset.zip" -d "/content/drive/MyDrive/Self Driving Cars/"

# %%
import tensorflow
import os
os.getcwd()
# Out:
# '/content'

# %%
# %cd /content/drive/MyDrive/Self Driving Cars
# Out:
# /content/drive/MyDrive/Self Driving Cars

# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 584.5/584.5 kB 26.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.3/203.3 kB 26.6 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8m.pt")  # load a pretrained model (recommended for training)
# Out:
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 182MB/s]

# %%
# !touch data.yamal

# %%
model.train(data = "/content/drive/MyDrive/Self Driving Cars/data.yamal", epochs = 20) # Fine Tune the model
# Out:
# Ultralytics YOLOv8.0.99 🚀 Python-3.10.11 torch-2.0.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/drive/MyDrive/Self Driving Cars/runs/detect/train/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/Self Driving Cars/Self Driving Cars Dataset/1478732068046357683_jpg.rf.903cfed05bb86ea7ce60522e2964db3c.jpg", save = True, save_txt = True)
# Out:
# image 1/1 /content/drive/MyDrive/Self Driving Cars/Self Driving Cars Dataset/1478732068046357683_jpg.rf.903cfed05bb86ea7ce60522e2964db3c.jpg: 640x640 3 cars, 2 pedestrians, 2 trucks, 38.1ms
# Speed: 3.6ms preprocess, 38.1ms inference, 2.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict
# 1 label saved to runs/detect/predict/labels
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
#  orig_img: array([[[136, 127, 124],
#          [135, 126, 123],
#          [133, 124, 121],
#          ...,
#          [169, 159, 152],
#          [169, 159, 152],
#          [169, 159, 152]],
#
# ...

# %% [markdown]
# #Prediction

# %%
infer = YOLO("/content/drive/MyDrive/Self Driving Cars/runs/detect/train/weights/best.pt")

# %%
image_path = '/content/drive/MyDrive/Self Driving Cars/Self Driving Cars Dataset/1478895510996014853_jpg.rf.61cbf6eeaab2d3bab34b13272a7d4cda.jpg'
infer.predict(image_path, conf=0.25)
# Out:
# image 1/1 /content/drive/MyDrive/Self Driving Cars/Self Driving Cars Dataset/1478895510996014853_jpg.rf.61cbf6eeaab2d3bab34b13272a7d4cda.jpg: 640x640 (no detections), 37.2ms
# Speed: 4.7ms preprocess, 37.2ms inference, 2.2ms postprocess per image at shape (1, 3, 640, 640)
# [ultralytics.yolo.engine.results.Results object with attributes:
#
#  boxes: ultralytics.yolo.engine.results.Boxes object
#  keypoints: None
#  keys: ['boxes']
#  masks: None
#  names: {0: 'biker', 1: 'car', 2: 'pedestrian', 3: 'trafficLight', 4: 'trafficLight-Green', 5: 'trafficLight-GreenLeft', 6: 'trafficLight-Red', 7: 'trafficLight-RedLeft', 8: 'trafficLight-Yellow', 9: 'trafficLight-YellowLeft', 10: 'truck'}
#  orig_img: array([[[242, 171, 138],
#          [240, 171, 138],
#          [238, 172, 137],
#          ...,
#          [255, 207, 161],
#          [255, 205, 160],
#          [255, 201, 154]],
#
#         [[252, 183, 150],
#          [249, 183, 148],
#          [246, 182, 147],
#          ...,
# ...

# %%
import cv2
from tensorflow.keras.preprocessing import image
from google.colab.patches import cv2_imshow # cv2.imshow does not work on Google Colab notebooks, which is why we are using cv2_imshow instead


ORIGINAL = '/content/drive/MyDrive/Self Driving Cars/runs/detect/predict/1478732068046357683_jpg.rf.903cfed05bb86ea7ce60522e2964db3c.jpg'

DIM = 224

img = image.load_img(ORIGINAL, target_size=(DIM, DIM))

cv2_imshow(cv2.imread(ORIGINAL)) # Visualize image
# Out:
# <PIL.Image.Image image mode=RGB size=512x512 at 0x7FC4202FAA10>
